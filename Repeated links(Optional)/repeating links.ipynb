# %%
import pandas as pd
df = pd.read_csv('RQ2+3.csv')
df
# Out:
#          SI     strata  count_domain            Domain  \
# 0         1     common          4334        github.com
# 1         6  sometimes             6       polyfill.io
# 2         9     common          4327        github.com
# 3        10     common          2252         npmjs.com
# 4        12  sometimes             9      jsdelivr.com
# ...     ...        ...           ...               ...
# 2120    142       rare             1        elastic.co
# 2121    296       rare             1  archive.uber.com
# 2122   1178       rare             1         google.de
# 2123  18394       rare             1  irc.freenode.net
# 2124   1393       rare             1       codepan.net
#
#                                                    text  \
# 0     @bitandbang this action can turn on automerge ...
# 1     @b0neskull @openjsf I run https://t.co/29YaS03...
# 2     @dependabot Is there a guide on how to publish...
# 3     @fquednau @polyfillio I don't think there are ...
# ...

# %%
link_counts = df['Link'].value_counts()
df_filtered = df[df['Link'].isin(link_counts[link_counts > 1].index)]
df_filtered['frequency'] = df_filtered['Link'].map(df_filtered['Link'].value_counts())
dff = df_filtered[['SI','strata','Domain','text','Link','RQ2 target','RQ3 perpose','RQ- category','frequency']]
dff
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5024\3538217621.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['frequency'] = df_filtered['Link'].map(df_filtered['Link'].value_counts())
#        SI     strata              Domain  \
# 1       6  sometimes         polyfill.io
# 6      29     common  engineering.fb.com
# 7      30     common          nodejs.org
# 8      32  sometimes          license.md
# 23    151  sometimes        substack.net
# ...   ...        ...                 ...
# 2109   23  sometimes     davidwalsh.name
# 2110   33  sometimes          license.md
# 2112  327  sometimes        joezimjs.com
# 2114  366  sometimes     fredkschott.com
# 2116  508  sometimes    semver.npmjs.com
#
# ...

# %%
dff['strata'].value_counts()
# Out:
# strata
# sometimes    203
# common       134
# Name: count, dtype: int64

# %%
dtt=dff['Domain'].value_counts()
dtt.head(30)
# Out:
# Domain
# hackernoon.com                    12
# semver.npmjs.com                  10
# wdp.joycalls.com                  10
# zdnet.com                         10
# overreacted.io                     8
# bundlephobia.com                   8
# npmjs.com                          8
# npm-stats.com                      8
# blog.cybozu.io                     8
# jser.info                          7
# package.community                  7
# registry.npmjs.org                 6
# zenn.dev                           6
# yosuke-furukawa.hatenablog.com     6
# mixmax.com                         6
# goodbye.paper.li                   6
# pnpm.js.org                        6
# hugedomains.com                    6
# opencollective.com                 5
# twilio.com                         5
# anvaka.github.io                   5
# blog.risingstack.com               5
# codeforgeek.com                    5
# davidwalsh.name                    4
# eslint.org                         4
# ...

# %%
dft=dff[['SI','strata','Domain','Link','RQ3 perpose','RQ- category','frequency']]
dft.to_csv('all_repeated_links.csv')

# %%
unique_links = dft.drop_duplicates(subset='Link')
#unique_links.to_csv('RQ5.csv')
unique_links
# Out:
#          SI     strata              Domain  \
# 1         6  sometimes         polyfill.io
# 6        29     common  engineering.fb.com
# 7        30     common          nodejs.org
# 8        32  sometimes          license.md
# 23      151  sometimes        substack.net
# ...     ...        ...                 ...
# 1865  15677  sometimes        joezimjs.com
# 1960  16370  sometimes         smddzcy.com
# 1988  16624  sometimes        campusmvp.es
# 2021  16898  sometimes  opencollective.com
# 2038  17033     common          github.com
#
#                                                    Link          RQ3 perpose  \
# 1                                  https://polyfill.io/           clarifying
# 6     https://engineering.fb.com/2016/10/11/web/yarn...    providing context
# 7     https://nodejs.org/en/blog/vulnerability/npm-t...  suggesting solution
# 8                                   https://license.md/           clarifying
# ...

# %%
#from pandas_profiling import ProfileReport
from ydata_profiling import ProfileReport
# Assuming 'df' is your DataFrame
prof = ProfileReport(dff)
prof.to_file(output_file='summary.html')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Analysis after manual part:

# %%
import pandas as pd
df = pd.read_csv('RQ5 result.csv')
df
# Out:
#         SI     strata              Domain  \
# 0     2586  sometimes    semver.npmjs.com
# 1     4482     common      hackernoon.com
# 2     6677  sometimes    wdp.joycalls.com
# 3      752  sometimes      overreacted.io
# 4     2386     common    bundlephobia.com
# ..     ...        ...                 ...
# 106  15677  sometimes    www.joezimjs.com
# 107  16370  sometimes         smddzcy.com
# 108  16624  sometimes    www.campusmvp.es
# 109  16898  sometimes  opencollective.com
# 110  17033     common          github.com
#
#                                                   Link          RQ3 perpose  \
# 0                            https://semver.npmjs.com/          elaborating
# 1                              https://hackernoon.com/    providing context
# 2                          http://wdp.joycalls.com/get          elaborating
# 3    https://overreacted.io/npm-audit-broken-by-des...    providing context
# ...

# %%
df['strata'].value_counts()
# Out:
# strata
# sometimes    67
# common       44
# Name: count, dtype: int64

# %%
dff=df[df['strata']=='common']
dff['rq-5 observation'].value_counts()
# Out:
# rq-5 observation
# same topic,same purpose    20
# diff topic,diff purpose    15
# same topic,diff purpose     7
# diff topic,same purpose     2
# Name: count, dtype: int64

# %%
dff=df[df['strata']=='sometimes']
dff['rq-5 observation'].value_counts()
# Out:
# rq-5 observation
# same topic,same purpose    26
# diff topic,diff purpose    22
# same topic,diff purpose    11
# diff topic,same purpose     8
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame
dff = df[df['strata'] == 'sometimes']

# Calculate value counts for 'rq-5 observation'
category_counts = dff['rq-5 observation'].value_counts()

# Extract labels and sizes from the value counts
labels = category_counts.index
sizes = category_counts.values

# Define colors for the pie chart
colors = plt.get_cmap('tab20').colors  # Use a colormap to handle multiple categories

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')

# Title
plt.title("dgkfdk")

# Show plot
plt.show()

# %%
# import matplotlib.pyplot as plt

# # Data for the pie charts
# data1 = [45.5, 34.1, 15.9, 4.5]
# labels1 = ['Same topic and purpose', 'Diff topic and purpose', 'Same topic and diff purpose', 'Diff topic and same purpose']

# data2 = [38.8, 32.8, 16.4, 11.9]

# # Gray shades for the pie slices
# colors = ['#d3d3d3', '#a9a9a9', '#808080', '#696969']

# # Wedge properties for outlines
# wedgeprops = {'edgecolor': 'black', 'linewidth': 0.8}

# # Function to format autopct values (horizontal alignment)
# def autopct_format(pct):
#     return f'{pct:.1f}%'

# # Create a figure with two subplots
# fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# # First pie chart
# wedges1, texts1, autotexts1 = axes[0].pie(
#     data1, autopct=autopct_format, startangle=0,
#     colors=colors, textprops={'fontsize': 9}, wedgeprops=wedgeprops
# )
# axes[0].text(0, 1.1, '(a) Commonly Shared', ha='center', fontsize=9)  # Title below the chart

# # Second pie chart
# wedges2, texts2, autotexts2 = axes[1].pie(
#     data2, startangle=90, colors=colors, autopct=autopct_format,
#     textprops={'fontsize': 8}, wedgeprops=wedgeprops
# )
# axes[1].text(0,1.1, '(b) Shared Sometimes', ha='center', fontsize=9)  # Title below the chart

# # Combine the legend
# fig.legend(labels1, loc='lower center', ncol=2, fontsize=9)

# # Adjust layout
# plt.tight_layout()  # Leave space for the legend at the bottom
# plt.savefig("repeated.pdf", format="pdf")
# plt.show()

# %%
import pandas as pd
df = pd.read_csv('RQ5 result.csv')
df
# Out:
#         SI     strata              Domain  \
# 0     2586  sometimes    semver.npmjs.com
# 1     4482     common      hackernoon.com
# 2     6677  sometimes    wdp.joycalls.com
# 3      752  sometimes      overreacted.io
# 4     2386     common    bundlephobia.com
# ..     ...        ...                 ...
# 106  15677  sometimes    www.joezimjs.com
# 107  16370  sometimes         smddzcy.com
# 108  16624  sometimes    www.campusmvp.es
# 109  16898  sometimes  opencollective.com
# 110  17033     common          github.com
#
#                                                   Link          RQ3 perpose  \
# 0                            https://semver.npmjs.com/          elaborating
# 1                              https://hackernoon.com/    providing context
# 2                          http://wdp.joycalls.com/get          elaborating
# 3    https://overreacted.io/npm-audit-broken-by-des...    providing context
# ...

# %%
df=df[['Link','frequency']]
df
# Out:
#                                                   Link  frequency
# 0                            https://semver.npmjs.com/         10
# 1                              https://hackernoon.com/         12
# 2                          http://wdp.joycalls.com/get         10
# 3    https://overreacted.io/npm-audit-broken-by-des...          8
# 4                            https://bundlephobia.com/          8
# ..                                                 ...        ...
# 106  https://www.joezimjs.com/javascript/no-more-gl...          2
# 107  https://smddzcy.com/posts/2019-05-19/npm-vs-ya...          2
# 108  https://www.campusmvp.es/recursos/post/como-pu...          2
# 109                  https://opencollective.com/gqless          2
# 110       https://github.com/aykutkardas/Json-Function          2
#
# [111 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

frequencies = df['frequency']

plt.figure(figsize=(8, 6))
plt.hist(frequencies, bins=np.arange(1, frequencies.max() + 2), edgecolor='black', alpha=0.75)

# Adding labels and formatting
plt.title("Distribution of links")
plt.xlabel("Link frequencies")
plt.ylabel("Total count (log)")


plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
